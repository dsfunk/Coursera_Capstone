# %% [markdown]
# # Coursera IBM Data Science Capstone Project.
#
# ### Comparing neighborhoods of Seattle using geo data and foursquare api.

# %% [markdown]
# Importing most of the libraries that I will need.

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import numpy as np

import requests # library to handle requests
import random # library for random number generation

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
import sklearn
from sklearn.cluster import KMeans

#!pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 

import json # library to handle JSON files
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

#! pip install folium==0.5.0
import folium # plotting library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
#Foursquare API credentials
CLIENT_ID = 'NERYLZJIO3LDMUIX2OVRYHTRNEPOYW34VBLMN1WCKPCCK0XP' # your Foursquare ID
CLIENT_SECRET = 'GILN0XA0CVK420FBZ0H2Q1EYAQKXDXDGMGDQ5LT2KAQPS3IV' # your Foursquare Secret
ACCESS_TOKEN = 'J0TME0XJXOAGSAJ5YQVV1JOKCH530CVDJIN5L5IU1OOYFQPX' # your FourSquare Access Token
VERSION = '20180604'

# %% [markdown]
# Using folium to build and view a map of Seattle.

# %%
sea_lat = 47.608013
sea_lon = -122.335167
map_seattle = folium.Map(location=[sea_lat, sea_lon], zoom_start=12)
    
map_seattle
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# I found a wiki page with a table containing Seattle neighborhoods.
# I am using BeautifulSoup to scrape the page and load a dataframe.

# %%
from bs4 import BeautifulSoup

# %%
req = requests.get("https://en.wikipedia.org/wiki/List_of_neighborhoods_in_Seattle")

soup = BeautifulSoup(req.content,'lxml')

table = soup.find_all('table')[0]

df1 = pd.read_html(str(table))

hoods = pd.DataFrame(df1[0])
hoods.head()
# Out:
#    Unnamed: 0         Neighborhood name Within larger district  \
# 0           1             North Seattle                Seattle
# 1           2                 Broadview      North Seattle[42]
# 2           3               Bitter Lake      North Seattle[42]
# 3           4  North Beach / Blue Ridge      North Seattle[42]
# 4           5                Crown Hill      North Seattle[42]
#
#                     Annexed[41]  Locator map  Street map  Image  \
# 0                       Various          NaN         NaN    NaN
# 1                      1954[43]          NaN         NaN    NaN
# 2                      1954[43]          NaN         NaN    NaN
# 3            1940,[43] 1954[43]          NaN         NaN    NaN
# 4  1907,[47] 1952,[43] 1954[43]          NaN         NaN    NaN
#
#                                          Notes
# 0  North of the Lake Washington Ship Canal[42]
# 1                                         [44]
# 2                                         [45]
# ...

# %% [markdown]
# ### Cleaning the data
# Unfortunately I could not find a source that already included geo coordinates for the neighborhoods.
# I just need the Neighborhood name from this data set, and will add coordinates later.
# There are also a couple of greater neighborhoods that are redundant so I am removing those.

# %%
#remove unwanted rows
hoods.drop( hoods[ (hoods['Neighborhood name'] == "North Seattle") | (hoods['Neighborhood name'] == "Central Seattle") | (hoods['Neighborhood name'] == "West Seattle") | (hoods['Neighborhood name'] == "Queen Anne")].index , inplace=True)

#remove unwanted columns
hoods.drop(['Unnamed: 0','Within larger district','Annexed[41]','Locator map','Street map','Image','Notes'], axis=1, inplace=True)

#rename column for less typing
hoods.rename(columns={'Neighborhood name':'Neighborhood'}, inplace=True)

#reset index after dropped rows
hoods = hoods.reset_index(drop=True)

hoods.head()
# Out:
#                Neighborhood
# 0                 Broadview
# 1               Bitter Lake
# 2  North Beach / Blue Ridge
# 3                Crown Hill
# 4                 Greenwood

# %%
hoods.shape
# Out:
# (123, 1)

# %% [markdown]
# Now to add the coordinates using geocoder and arcgis.

# %%
#!pip install geocoder
import geocoder

# %%
latitude=[]
longitude=[]
for row in hoods['Neighborhood']:
    g = geocoder.arcgis('{}, Seattle, Washington'.format(row))
    print(row, g.latlng)
    while (g.latlng is None):
        g = geocoder.arcgis('{}, Seattle, Washington'.format(row))
        print(row, g.latlng)
    latlng = g.latlng
    latitude.append(latlng[0])
    longitude.append(latlng[1])
# Out:
# Broadview [47.722380000000044, -122.36497999999995]
# Bitter Lake [47.71868000000006, -122.35029999999995]
# North Beach / Blue Ridge [47.70044000000007, -122.38417999999996]
# Crown Hill [47.69520000000006, -122.37409999999994]
# Greenwood [47.69082000000003, -122.35528999999997]
# Northgate [47.713100000000054, -122.31929999999994]
# Haller Lake [47.72320000000008, -122.33869999999996]
# Pinehurst [47.71894000000003, -122.31399999999996]
# North College Park (Licton Springs) [47.69914000000006, -122.33967999999999]
# Maple Leaf [47.70013000000006, -122.31764999999996]
# Lake City [47.71780000000007, -122.28317999999996]
# Cedar Park [47.72645000000006, -122.28800999999999]
# Matthews Beach [47.69934000000006, -122.27834999999999]
# Meadowbrook [47.70841000000007, -122.29585999999995]
# Olympic Hills [47.72656000000006, -122.30259999999998]
# Victory Heights [47.710300000000075, -122.30719999999997]
# Wedgwood [47.68701000000004, -122.29493999999994]
# ...

# %%
#append the coordinates to the dataframe
hoods['Latitude'] = latitude
hoods['Longitude'] = longitude

# %%
hoods.shape
# Out:
# (123, 3)

# %% [markdown]
# Now I am redrawing the Seattle map with neighborhood markers.

# %%
sea_lat = 47.608013
sea_lon = -122.335167
map_seattle = folium.Map(location=[sea_lat, sea_lon], zoom_start=11)

# add markers to map
for lat, lng, neighborhood in zip(hoods['Latitude'], hoods['Longitude'], hoods['Neighborhood']):
    label = '{}'.format(neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_seattle)  
    
map_seattle
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now we will get venue data via the foursquare api, and create a larger dataframe merging the hoods dataframe.

# %%
#define a function to gather venues for all of our hoods using a 1000 meter radius from each hood coordinates.

#amount of results per hood
LIMIT = 40
#looking for ?
query = ""
#I would like to get ratings as well, but that is a premium call on foursquare's api

def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&query={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            query, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        #print(type(results))
        
        # return only relevant information for each nearby venue
        #results.setdefault('address', 'Not Present') 
        #defd = results.defaultdict(lambda : 'Key Not found') 
        #resultsdic = json.loads(str(results))
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'], 
            #v['venue']['location']['address'], 
            #v['venue']['location']['address'].get(v['venue']['location']['address'],''), 
            v['venue']['categories'][0]['name']) for v in results])
    
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
venues = getNearbyVenues(names=hoods['Neighborhood'],
                                   latitudes=hoods['Latitude'],
                                   longitudes=hoods['Longitude']
                                  )
# Out:
# Broadview
# Bitter Lake
# North Beach / Blue Ridge
# Crown Hill
# Greenwood
# Northgate
# Haller Lake
# Pinehurst
# North College Park (Licton Springs)
# Maple Leaf
# Lake City
# Cedar Park
# Matthews Beach
# Meadowbrook
# Olympic Hills
# Victory Heights
# Wedgwood
# View Ridge
# Sand Point
# Roosevelt
# Ravenna
# Bryant
# Windermere
# Hawthorne Hills
# Laurelhurst
# University District (U District)
# University Village
# Wallingford
# Northlake
# Green Lake
# Fremont
# Phinney Ridge
# Ballard
# West Woodland
# Whittier Heights
# Adams
# Sunset Hill
# Loyal Heights
# Magnolia
# Lawton Park
# Briarcliff
# Southeast Magnolia
# Interbay
# North Queen Anne
# East Queen Anne
# Lower Queen Anne
# West Queen Anne
# Capitol Hill
# Portage Bay[95] / Roanoke
# Broadway
# Pike-Pine Corridor / Pike/Pine[97][98][99]
# Montlake
# Stevens
# Interlaken
# Madison Valley
# Renton Hill
# Madison Park
# Broadmoor
# Lake Union
# South Lake Union, Seattle
# Cascade, Seattle
# Westlake
# Eastlake
# ...

# %%
print(venues.shape)
venues.head()
# Out:
# (251, 7)
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Bitter Lake               47.71868               -122.3503
# 1   Crown Hill               47.69520               -122.3741
# 2   Crown Hill               47.69520               -122.3741
# 3  Haller Lake               47.72320               -122.3387
# 4    Pinehurst               47.71894               -122.3140
#
#                   Venue  Venue Latitude  Venue Longitude       Venue Category
# 0       Jack in the Box       47.720318      -122.345448         Burger Joint
# 1       Dick's Drive-In       47.696500      -122.371748         Burger Joint
# 2    Wild Mountain Cafe       47.690779      -122.374559  American Restaurant
# 3             Rain Cafe       47.724808      -122.343854                 Café
# 4  Boud's Pinehurst Pub       47.715641      -122.312633                  Bar

# %% [markdown]
# I want to remove the category of Fast Food Restaurant.

# %%
#remove unwanted rows
venues.drop( venues[ (venues['Venue Category'] == "Fast Food Restaurant")].index , inplace=True)

# %%
print(venues.shape)
venues.head()
# Out:
# (251, 7)
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Bitter Lake               47.71868               -122.3503
# 1   Crown Hill               47.69520               -122.3741
# 2   Crown Hill               47.69520               -122.3741
# 3  Haller Lake               47.72320               -122.3387
# 4    Pinehurst               47.71894               -122.3140
#
#                   Venue  Venue Latitude  Venue Longitude       Venue Category
# 0       Jack in the Box       47.720318      -122.345448         Burger Joint
# 1       Dick's Drive-In       47.696500      -122.371748         Burger Joint
# 2    Wild Mountain Cafe       47.690779      -122.374559  American Restaurant
# 3             Rain Cafe       47.724808      -122.343854                 Café
# 4  Boud's Pinehurst Pub       47.715641      -122.312633                  Bar

# %%
#jack in the box is trying to sneak in there as a Burger Joint instead of a fast food
venues.drop( venues[ (venues['Venue'] == "Jack in the Box")].index , inplace=True)

# %%
print(venues.shape)
venues.head()
# Out:
# (245, 7)
#                           Neighborhood  Neighborhood Latitude  \
# 1                           Crown Hill               47.69520
# 2                           Crown Hill               47.69520
# 3                          Haller Lake               47.72320
# 4                            Pinehurst               47.71894
# 5  North College Park (Licton Springs)               47.69914
#
#    Neighborhood Longitude                 Venue  Venue Latitude  \
# 1              -122.37410       Dick's Drive-In       47.696500
# 2              -122.37410    Wild Mountain Cafe       47.690779
# 3              -122.33870             Rain Cafe       47.724808
# 4              -122.31400  Boud's Pinehurst Pub       47.715641
# 5              -122.33968          Burgermaster       47.701233
#
#    Venue Longitude       Venue Category
# 1      -122.371748         Burger Joint
# 2      -122.374559  American Restaurant
# 3      -122.343854                 Café
# ...

# %% [markdown]
# Good! I got rid of Jack in the Boxes

# %% [markdown]
# ## Time to explore the data a little.

# %%
# group by neighborhood to see how many venues exist for each in the query result 
burger_sum = venues.groupby('Neighborhood', axis=0).count()
burger_sum.head()
# Out:
#               Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Adams                             4                       4      4
# Ballard                           8                       8      8
# Belltown                          9                       9      9
# Broadway                          3                       3      3
# Capitol Hill                      3                       3      3
#
#               Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Adams                      4                4               4
# Ballard                    8                8               8
# Belltown                   9                9               9
# Broadway                   3                3               3
# Capitol Hill               3                3               3

# %%
burger_sum2 = burger_sum.rename(columns={'Neighborhood Latitude':'Venues'})
burger_sum2.drop(['Neighborhood Longitude', 'Venue', 'Venue Latitude', 'Venue Longitude', 'Venue Category'], axis=1, inplace=True)
burger_sum2.head()
# Out:
#               Venues
# Neighborhood
# Adams              4
# Ballard            8
# Belltown           9
# Broadway           3
# Capitol Hill       3

# %% [markdown]
# I want to visualize this with all neighborhoods.

# %%
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
burger_sum2.plot(kind='bar', figsize=(25, 8), rot=90)

plt.xlabel('Neighborhood') # add to x-label to the plot
plt.ylabel('Burger Venues') # add y-label to the plot
plt.title('Seattle Burger Distribution') # add title to the plot

plt.show()

# %% [markdown]
# I can see that some of the denser neighborhoods returned the limit for venues.  I could raise the limit in the api call if I was concerned about accuracy.  I could also decrease the radius as some of these hoods are small.
#
# Now I want to visualize what the venue categories are.

# %%
# group by category to see how many venues exist for each in the query result 
cat_count = venues.groupby('Venue Category', axis=0).count()

# %%
cat_count2 = cat_count.rename(columns={'Neighborhood':'Venues'})
cat_count2.drop(['Neighborhood Latitude', 'Neighborhood Longitude', 'Venue', 'Venue Latitude', 'Venue Longitude'], axis=1, inplace=True)
cat_count2.head()
# Out:
#                      Venues
# Venue Category
# American Restaurant      19
# BBQ Joint                 1
# Bar                      12
# Breakfast Spot            3
# Brewery                   2

# %%
cat_count2.plot(kind='bar', figsize=(25, 8), rot=90)

plt.xlabel('Category') # add to x-label to the plot
plt.ylabel('Burger Venues') # add y-label to the plot
plt.title('Seattle Burger Distribution') # add title to the plot

plt.show()

# %% [markdown]
# What in the world does a financial or legal service have a burger mention for?

# %%
venues[venues['Venue Category'] == "Financial or Legal Service"]
# Out:
#                                    Neighborhood  Neighborhood Latitude  \
# 56   Pike-Pine Corridor / Pike/Pine[97][98][99]              47.608467
# 144                                 Pike-Market              47.610850
#
#      Neighborhood Longitude          Venue  Venue Latitude  Venue Longitude  \
# 56              -122.340153  Cafe Campagne       47.609654      -122.341481
# 144             -122.342230  Cafe Campagne       47.609654      -122.341481
#
#                  Venue Category
# 56   Financial or Legal Service
# 144  Financial or Legal Service

# %% [markdown]
# It looks like it is marked with the wrong category.  It is a restaurant, but they do not normaly have a burger.  I will remove the category.

# %% [markdown]
# I made some changes to the API query to get a venues dataframe that includes more than burgers to join to the seattle dataset below.

# %%
venues2 = getNearbyVenues(names=hoods['Neighborhood'],
                                   latitudes=hoods['Latitude'],
                                   longitudes=hoods['Longitude']
                                  )
# Out:
# Broadview
# Bitter Lake
# North Beach / Blue Ridge
# Crown Hill
# Greenwood
# Northgate
# Haller Lake
# Pinehurst
# North College Park (Licton Springs)
# Maple Leaf
# Lake City
# Cedar Park
# Matthews Beach
# Meadowbrook
# Olympic Hills
# Victory Heights
# Wedgwood
# View Ridge
# Sand Point
# Roosevelt
# Ravenna
# Bryant
# Windermere
# Hawthorne Hills
# Laurelhurst
# University District (U District)
# University Village
# Wallingford
# Northlake
# Green Lake
# Fremont
# Phinney Ridge
# Ballard
# West Woodland
# Whittier Heights
# Adams
# Sunset Hill
# Loyal Heights
# Magnolia
# Lawton Park
# Briarcliff
# Southeast Magnolia
# Interbay
# North Queen Anne
# East Queen Anne
# Lower Queen Anne
# West Queen Anne
# Capitol Hill
# Portage Bay[95] / Roanoke
# Broadway
# Pike-Pine Corridor / Pike/Pine[97][98][99]
# Montlake
# Stevens
# Interlaken
# Madison Valley
# Renton Hill
# Madison Park
# Broadmoor
# Lake Union
# South Lake Union, Seattle
# Cascade, Seattle
# Westlake
# Eastlake
# ...

# %%
#perform the cleaning again
venues2.drop( venues2[ (venues2['Venue Category'] == "Fast Food Restaurant")].index , inplace=True)
venues2.drop( venues2[ (venues2['Venue'] == "Jack in the Box")].index , inplace=True)
venues2.drop( venues2[ (venues2['Venue Category'] == "Financial or Legal Service")].index , inplace=True)
venues2.drop( venues2[ (venues2['Venue Category'] == "Convenience Store")].index , inplace=True)
venues2.shape
# Out:
# (2148, 7)

# %% [markdown]
# Cleaned the data to make it more valid.

# %%
venues2[venues2['Neighborhood'] == "Belltown"]
# Out:
#      Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 1160     Belltown               47.61576              -122.34464
# 1161     Belltown               47.61576              -122.34464
# 1162     Belltown               47.61576              -122.34464
# 1163     Belltown               47.61576              -122.34464
# 1164     Belltown               47.61576              -122.34464
# 1165     Belltown               47.61576              -122.34464
# 1166     Belltown               47.61576              -122.34464
# 1167     Belltown               47.61576              -122.34464
# 1168     Belltown               47.61576              -122.34464
# 1169     Belltown               47.61576              -122.34464
# 1170     Belltown               47.61576              -122.34464
# 1171     Belltown               47.61576              -122.34464
# 1172     Belltown               47.61576              -122.34464
# ...

# %%
venues2[venues2['Venue'].str.contains("Dick")]
# Out:
#          Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 34         Crown Hill               47.69520              -122.37410
# 655  Lower Queen Anne               47.62459              -122.35757
#
#                Venue  Venue Latitude  Venue Longitude Venue Category
# 34   Dick's Drive-In       47.696500      -122.371748   Burger Joint
# 655  Dick's Drive-In       47.623413      -122.356589   Burger Joint

# %% [markdown]
# These look like good results.

# %% [markdown]
# Now going to pull in the Seattle restaurant operating data.

# %%
cos_df = pd.read_csv('Restaurants_Operating_during_COVID19.csv')

# %%
cos_df.head()
# Out:
#             X          Y  objectid                              globalid  \
# 0 -122.318799  47.613362         3  12aba10d-7825-45cb-ac38-46b22e670698
# 1 -122.314425  47.614776         4  4b271d79-3283-4e16-bd59-cfadca726051
# 2 -122.328084  47.614436         5  f4928649-888c-41be-9726-4eb86ae05a08
# 3 -122.326795  47.598599         6  0745b48d-87a3-4c4e-9910-24340784a738
# 4 -122.321425  47.581182         7  0afb2fdb-9ef1-430a-8757-beafc610fd24
#
#           business_name       address_help_your_customer_find  \
# 0                Bateau    1040 E Union St, Seattle, WA 98122
# 1                   Nue                         1519 14th Ave
# 2           Terra Plata    1501 Melrose Ave Seattle, WA 98122
# 3  A+ Hong Kong Kitchen      419 6th Ave S, Seattle, WA 98104
# 4             Gourmondo  2415 Airport Way S. Seattle WA 98134
#
#   phone_number_to_place_an_order  \
# 0                   206-900-8699
# 1                   206-257-0312
# 2                 (206) 325-1501
# ...

# %%
cos_df[cos_df['business_name'].str.contains("Random")]
# Out:
#               X          Y  objectid                              globalid  \
# 721 -122.349791  47.615518       818  74138a75-dff3-428a-8c71-b44f2a6fd6f3
#
#        business_name address_help_your_customer_find  \
# 721  Some Random Bar                    2604 1st Ave
#
#     phone_number_to_place_an_order          business_website  \
# 721                     2067286621  http://somerandombar.com
#
#                          are_you_open_for  \
# 721  takeout,third_party_delivery_service
#
#                        provide_details_for_you_busines  \
# 721  Lunch M-F 11am-2pm \nDinner Every Night 5pm-9p...
#
#                    CreationDate                    EditDate
# 721  2020/04/01 07:05:16.677+00  2020/04/01 07:05:16.677+00

# %% [markdown]
# The location data is not identical to foursquare I will need to use something else to merge.

# %% [markdown]
# I need to get rid of non-Seattle addresses.  The dataset contains all of King county.

# %%
cos_clean = cos_df[cos_df['address_help_your_customer_find'].str.contains("Seattle", na=False)]

# %%
#remove unwanted columns
cos_clean.drop(['X','Y','objectid','globalid','CreationDate','EditDate',], axis=1, inplace=True)

#rename column for less typing
cos_clean.rename(columns={'address_help_your_customer_find':'address'}, inplace=True)
cos_clean.rename(columns={'phone_number_to_place_an_order':'phone'}, inplace=True)
cos_clean.rename(columns={'are_you_open_for':'service'}, inplace=True)
cos_clean.rename(columns={'provide_details_for_you_busines':'hours_details'}, inplace=True)
# Out:
# C:\Users\DaveFunk\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# C:\Users\DaveFunk\Anaconda3\lib\site-packages\pandas\core\frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
cos_clean = cos_clean.reset_index(drop=True)
print(cos_clean.shape)
cos_clean.head()
# Out:
# (1128, 6)
#           business_name                                    address  \
# 0                Bateau         1040 E Union St, Seattle, WA 98122
# 1           Terra Plata         1501 Melrose Ave Seattle, WA 98122
# 2  A+ Hong Kong Kitchen           419 6th Ave S, Seattle, WA 98104
# 3             Gourmondo       2415 Airport Way S. Seattle WA 98134
# 4             Lady Jaye  4523 California Ave SW, Seattle, WA 98116
#
#             phone                                   business_website  \
# 0    206-900-8699                  https://www.restaurantbateau.com/
# 1  (206) 325-1501                         http://www.terraplata.com/
# 2    206-682-1267           https://www.facebook.com/aplushkkitchen/
# 3    206-587-0190  https://catering.gourmondoco.com/index.cfm?fus...
# 4    206-457-4029                          https://www.ladyjaye.com/
#
#                                          service  \
# 0                                       curbside
# ...

# %% [markdown]
# The address field is not in a consistent format so I need to split it and clean up the street.

# %%
cos_clean[['street','leftover']] = cos_clean.address.str.split("Seattle", n=1, expand=True)
cos_clean['street'] = cos_clean['street'].str.replace(',', '')
cos_clean.drop(['leftover','address'], axis=1, inplace=True)
cos_clean.head()
# Out:
#           business_name           phone  \
# 0                Bateau    206-900-8699
# 1           Terra Plata  (206) 325-1501
# 2  A+ Hong Kong Kitchen    206-682-1267
# 3             Gourmondo    206-587-0190
# 4             Lady Jaye    206-457-4029
#
#                                     business_website  \
# 0                  https://www.restaurantbateau.com/
# 1                         http://www.terraplata.com/
# 2           https://www.facebook.com/aplushkkitchen/
# 3  https://catering.gourmondoco.com/index.cfm?fus...
# 4                          https://www.ladyjaye.com/
#
#                                          service  \
# 0                                       curbside
# 1  takeout,curbside,third_party_delivery_service
# 2           takeout,third_party_delivery_service
# 3                                       delivery
# 4                                        takeout
#
#                                        hours_details                   street
# ...

# %%
merged_df = pd.merge(venues2, cos_clean, how='inner', left_on= 'Venue', right_on = 'business_name')

# %%
print(merged_df.shape)
merged_df.head()
# Out:
# (228, 13)
#                    Neighborhood  Neighborhood Latitude  \
# 0                    Crown Hill               47.69520
# 1                    Crown Hill               47.69520
# 2  Seaview[155] / Mee-Kwa-Mooks               47.55217
# 3                Fairmount Park               47.55341
# 4                     Greenwood               47.69082
#
#    Neighborhood Longitude                            Venue  Venue Latitude  \
# 0              -122.37410               Wild Mountain Cafe       47.690779
# 1              -122.37410                Papa John's Pizza       47.694423
# 2              -122.39175                Papa John's Pizza       47.554182
# 3              -122.38160                Papa John's Pizza       47.554182
# 4              -122.35529  Flying Bike Cooperative Brewery       47.692123
#
#    Venue Longitude       Venue Category                    business_name  \
# 0      -122.374559  American Restaurant               Wild Mountain Cafe
# ...

# %%
count_df = merged_df.groupby(['Neighborhood'], axis=0).count()
count_df2 = count_df.rename(columns={'Neighborhood Latitude':'Venues'})
count_df2.drop(['Neighborhood Longitude', 'Venue', 'Venue Latitude', 'Venue Longitude', 'Venue Category','business_name', 'phone', 'business_website', 'service', 'hours_details', 'street'], axis=1, inplace=True)

# %%
count_df2.sort_values(by=['Venues'])
# Out:
#                                                     Venues
# Neighborhood
# Wallingford                                              1
# Whittier Heights                                         1
# Laurelhurst                                              1
# Wedgwood                                                 1
# Washington Park                                          1
# Highland Park                                            1
# Haller Lake                                              1
# Genesee                                                  1
# Northgate                                                1
# Lower Queen Anne                                         1
# Fairmount Park                                           1
# Northlake                                                1
# Fauntleroy                                               1
# Brighton                                                 1
# Alki Point                                               1
# ...

# %%
count_df3 = count_df2.sort_values(by=['Venues'])

count_df3.plot(kind='bar', figsize=(25, 8), rot=90)

plt.xlabel('Neighborhood') # add to x-label to the plot
plt.ylabel('Venues') # add y-label to the plot
plt.title('Restaurants open for service during COVID') # add title to the plot

plt.show()

# %%
#Taking a look at my neighborhood
merged_df[merged_df['Neighborhood'] == "Georgetown"]
# Out:
#     Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 31    Georgetown               47.54751              -122.32149
# 206   Georgetown               47.54751              -122.32149
# 207   Georgetown               47.54751              -122.32149
# 208   Georgetown               47.54751              -122.32149
#
#                          Venue  Venue Latitude  Venue Longitude  \
# 31                   Starbucks       47.546040      -122.325593
# 206  Jellyfish Brewing Company       47.548936      -122.320457
# 207               Smarty Pants       47.548862      -122.316593
# 208      Machine House Brewery       47.550350      -122.317303
#
#     Venue Category              business_name           phone  \
# 31     Coffee Shop                  Starbucks  (206) 496-8523
# 206        Brewery  Jellyfish Brewing Company    206.397.4999
# 207            Bar               Smarty Pants  (206) 762-4777
# 208        Brewery      Machine House Brewery    206-402-6025
#
# ...
